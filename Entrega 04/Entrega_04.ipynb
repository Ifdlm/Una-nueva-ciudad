# %%
import seaborn as sns

# Numero de comunas que seleccioné
x = ["Maipú", "Puente Alto", "Quilicura", "Lampa", "Cerro Navia", "Pudahuel"]
# El eje Y muestra el número de vertederos ilegales por comuna
y = [8, 6, 9, 8, 2, 11]

# Colores de las barritas por comuna
colores = ["#0000FF", "#FF0000", "#FFFF00", "#008000", "#FFC0CB", "#800080"]

sns.barplot(x=x, y=y, palette=colores)

# La elección de colores es arbitraria para diferenciar cada comuna

plt.title("Vertederos ilegales por comuna en la Región Metropolitana")
plt.xlabel("Comunas")
plt.ylabel("N° de vertederos ilegales")

plt.show()
