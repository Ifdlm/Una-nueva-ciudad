# %%
from google.colab import drive
drive.mount('/content/drive')
#Acá otorgué los permisos para que Google Colab acceda a mi Google Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/DatosHoja1.csv'

# %%
import seaborn as sns

#Acá va la información para las columnas y datos

data = {'COMUNAS': ['Lampa', 'Pudahuel', 'Puente Alto', 'Quilicura', 'Las Condes', 'Paine'],
        'CANTIDAD DE VERTEDEROS': [8, 8, 6, 6, 0, 1]}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
#Acá van los textos, títulos para el archivo
sns.barplot(x='COMUNAS', y='CANTIDAD DE VERTEDEROS', data=df)
plt.title('CANTIDAD DE VERTEDEROS ILEGALES POR COMUNA EN LA RM')
plt.xlabel('Comuna')
plt.ylabel('Cantidad de Vertederos')
plt.show()

# %%
#Acá le dí las indicaciones para abrir un nuevo archivo y trabajar con él
file_path = '/content/drive/MyDrive/DATOSPORREGIÓN.csv'

# %%
import seaborn as sns

# Acá ingresé los datos respectivo a cada comuna
data_nuevo = {'Region': ['Metropolitana', 'Valparaiso', 'Bio Bio'],
              'Porcentaje de toneladas': [40.9, 10.5, 9.5]}
df_nuevo = pd.DataFrame(data_nuevo)

# Acá las instrucciones para la visualización
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Porcentaje de toneladas', data=df_nuevo)
plt.title('Porcentaje de toneladas de residuos por Región')
plt.xlabel('Región')
plt.ylabel('Porcentaje de Toneladas')
plt.show()
